# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# ### Библиотеки:

# %%
import numpy as np
import pandas as pd

from pymorphy2 import MorphAnalyzer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %% [markdown]
# ### Файлы

# %% [markdown]
# #### Список фраз

# %% [markdown]
# Формат xlsx:

# %%
df = pd.read_excel('keywords.xlsx')

# %% [markdown]
# Формат csv:

# %%
#df = pd.read_csv('keywords.csv')

# %% [markdown]
# Из txt файла:

# %%
#keywords = [phrase.rstrip() for phrase in open('keywords.txt')]

# %%
#df = pd.DataFrame(keywords, columns=['Фраза'])

# %% [markdown]
# #### Загрузка стоп-слов

# %%
list_of_stop_words = pd.read_excel('spisok_stop_slov.xlsx', names=['stop_slova'])

# %% [markdown]
# #### Список предлогов

# %%
list_of_pretext = pd.read_excel('spisok_predlogov.xlsx', names=['predlogi'])

# %% [markdown]
# #### Список городов

# %%
list_of_cities = pd.read_excel('spisok_gorodov.xlsx', names=['goroda'])

# %% [markdown]
# #### Список вопросительных слов

# %%
list_of_questions = pd.read_excel('spisok_vopros_slov.xlsx', names=['vopros'])

# %% [markdown]
# #### Список "коммерческих" слов

# %%
list_of_commerce_words = pd.read_excel('spisok_kommercheskih_slov.xlsx', names=['komm'])

# %% [markdown]
# ## Удаление стоп слов

# %% [markdown]
# Разделение фразы на слова:

# %%
df['Фраза_по_словам'] = df['Фраза'].str.split()

# %%
df
# Out:
#                                                   Фраза  Базовая частота  \
# 0                                 ремонт гидроцилиндров              794
# 1                           ремонт гидроцилиндров в спб              173
# 2                            вира ремонт гидроцилиндров              107
# 3                        вира ремонт гидроцилиндров спб               77
# 4                            ремонт штока гидроцилиндра               24
# ...                                                 ...              ...
# 3236              справочник по термообработке металлов                1
# 3237                   лазерная термообработка металлов                1
# 3238                     методы термообработки металлов                1
# 3239                           термообработка металла 5                1
# 3240  справочник по термообработке металлов скачать ...                1
#
#       Частота **  Частота *!*  \
# 0            158          153
# 1            111          111
# 2             27           27
# 3             55           55
# 4              7            6
# ...          ...          ...
# 3236           0            0
# 3237           0            0
# 3238           0            0
# 3239           0            0
# 3240           1            1
#
#                                         Фраза_по_словам
# 0                              [ремонт, гидроцилиндров]
# 1                      [ремонт, гидроцилиндров, в, спб]
# 2                        [вира, ремонт, гидроцилиндров]
# 3                   [вира, ремонт, гидроцилиндров, спб]
# 4                        [ремонт, штока, гидроцилиндра]
# ...                                                 ...
# 3236         [справочник, по, термообработке, металлов]
# 3237               [лазерная, термообработка, металлов]
# 3238                 [методы, термообработки, металлов]
# 3239                       [термообработка, металла, 5]
# 3240  [справочник, по, термообработке, металлов, ска...
#
# [3241 rows x 5 columns]

# %% [markdown]
# Поиск совпадений. Если фраза содержит стоп-слово, значение меняется на 'stop':

# %%
def find_stop_words(splitted_phrase):
    for word in list_of_stop_words['stop_slova']:
        if word in splitted_phrase:
            return 'stop'

# %% [markdown]
# К столбцу "Фраза_по_словам" применяется функция, результат записывается в новый столбец "Содержит_стоп_слово":

# %%
df['Содержит_стоп_слово'] = df['Фраза_по_словам'].apply(find_stop_words)

# %% [markdown]
# Отбрасывание строк, которые содержат фразу со стоп-словами:

# %%
df.drop(df[df['Содержит_стоп_слово'] == 'stop'].index, inplace=True)

# %% [markdown]
# Удаление столбцов, который использовались для стоп-слов:

# %%
df.drop(columns = ['Содержит_стоп_слово', 'Фраза_по_словам'], inplace=True)

# %% [markdown]
# ## Удаление фраз с низкой частотностью

# %%
#df.drop(df[df['Частота **'] == 0].index, inplace=True)

# %% [markdown]
# ## Лемматизация ключевых слов:

# %% [markdown]
# Запись экземпляра класса в переменную m:

# %%
m = MorphAnalyzer()

# %% [markdown]
# Лемматизация через PyMorphy и добавление результатов в новый столбец:

# %%
df['Леммы'] = [' '.join([m.parse(word)[0].normal_form for word in x.split()]) for x in df['Фраза']]

# %%
df
# Out:
#                                       Фраза  Базовая частота  Частота **  \
# 0                     ремонт гидроцилиндров              794         158
# 1               ремонт гидроцилиндров в спб              173         111
# 2                вира ремонт гидроцилиндров              107          27
# 3            вира ремонт гидроцилиндров спб               77          55
# 4                ремонт штока гидроцилиндра               24           7
# ...                                     ...              ...         ...
# 3234   печь для термообработки металла цена                1           0
# 3235    термообработка металлов презентация                1           0
# 3236  справочник по термообработке металлов                1           0
# 3237       лазерная термообработка металлов                1           0
# 3239               термообработка металла 5                1           0
#
#       Частота *!*                                Леммы
# 0             153                  ремонт гидроцилиндр
# 1             111            ремонт гидроцилиндр в спб
# 2              27             вира ремонт гидроцилиндр
# 3              55         вира ремонт гидроцилиндр спб
# 4               6             ремонт шток гидроцилиндр
# ...           ...                                  ...
# 3234            0  печь для термообработка металл цена
# 3235            0    термообработка металл презентация
# 3236            0  справочник по термообработка металл
# 3237            0       лазерный термообработка металл
# 3239            0              термообработка металл 5
#
# [3080 rows x 5 columns]

# %% [markdown]
# ## Векторизация

# %% [markdown]
# ### Создание экземпляра класса TfidfVectorizer(min_df=1)

# %%
tvidf_v = TfidfVectorizer(min_df=1)

# %% [markdown]
# ### Обучение векторизатора леммам и преобразование набора данных

# %%
vectorized_lemmas = tvidf_v.fit_transform(df['Леммы'])

# %% [markdown]
# Чтобы посмотреть, как выглядят векторизованные фразы:

# %%
#pd.DataFrame(data=vectorized_lemmas.toarray(), columns=tvidf_v.get_feature_names(), index=df['Леммы'])

# %% [markdown]
# ## Кластеризация

# %% [markdown]
# Настройка KMeans:

# %%
km_clustering = KMeans(
    n_clusters=int(np.round(np.divide(len(df['Леммы']), 5))),
    init='k-means++',
    n_init=10,
    max_iter=300,
    tol=0.0001
                    )

# %% [markdown]
# Кластеризация и запись кластеров в столбец:

# %%
df['Кластер'] = km_clustering.fit_predict(vectorized_lemmas)

# %% [markdown]
# Сортировка по возрастанию номера кластера:

# %%
df.sort_values(by='Кластер', inplace=True)

# %%
df
# Out:
#                                                   Фраза  Базовая частота  \
# 926                           сварочные работы за тонну               99
# 1209       сварочные работы за тонну металлоконструкций               19
# 1105  стоимость сварочно монтажных работ трубопровод...               29
# 1199              цена сварочных работ за тонну металла               20
# 961                  стоимость сварочных работ за тонну               71
# ...                                                 ...              ...
# 3239                           термообработка металла 5                1
# 618           машиностроение и металлообработка в китае                2
# 459                            металлообработка в китае                5
# 640                 ищу исполнителя по металлообработке                2
# 609                        металлообработка исполнители                3
#
#       Частота **  Частота *!*  \
# 926            1            0
# 1209           1            1
# 1105          29           29
# 1199          20           20
# 961           28           28
# ...          ...          ...
# 3239           0            0
# 618            0            0
# 459            2            2
# 640            0            0
# 609            0            0
#
#                                                   Леммы  Кластер
# 926                           сварочный работа за тонна        0
# 1209       сварочный работа за тонна металлоконструкция        0
# 1105  стоимость сварочный монтажный работа трубопров...        0
# 1199              цена сварочный работа за тонна металл        0
# 961                 стоимость сварочный работа за тонна        0
# ...                                                 ...      ...
# 3239                            термообработка металл 5      613
# 618           машиностроение и металлообработка в китай      614
# 459                            металлообработка в китай      614
# 640              искать исполнитель по металлообработка      615
# 609                        металлообработка исполнитель      615
#
# [3080 rows x 6 columns]

# %% [markdown]
# ### Вывод

# %% [markdown]
# Кластеризация завершена, каждой фразе присвоен номер кластера. Следующие шаги в разделе постобработка не являются обязательными. Кластеризованный датафрейм можно экспортировать:

# %%
#writer_kernel = pd.ExcelWriter('ready_table.xlsx', engine='xlsxwriter')
#df.to_excel(writer_kernel)
#writer_kernel.save()

# %% [markdown]
# ## Постобработка

# %% [markdown]
# ### Присвоим название каждому кластеру

# %% [markdown]
# Копирование датафрейма:

# %%
df2 = df.copy()

# %% [markdown]
# Создание нового столбца "Название кластера" и запись в него разбитых на слова фраз из столбца "Леммы":

# %%
df2['Название_кластера'] = df2['Леммы'].str.split()

# %%
df2
# Out:
#                                                   Фраза  Базовая частота  \
# 926                           сварочные работы за тонну               99
# 1209       сварочные работы за тонну металлоконструкций               19
# 1105  стоимость сварочно монтажных работ трубопровод...               29
# 1199              цена сварочных работ за тонну металла               20
# 961                  стоимость сварочных работ за тонну               71
# ...                                                 ...              ...
# 3239                           термообработка металла 5                1
# 618           машиностроение и металлообработка в китае                2
# 459                            металлообработка в китае                5
# 640                 ищу исполнителя по металлообработке                2
# 609                        металлообработка исполнители                3
#
#       Частота **  Частота *!*  \
# 926            1            0
# 1209           1            1
# 1105          29           29
# 1199          20           20
# 961           28           28
# ...          ...          ...
# 3239           0            0
# 618            0            0
# 459            2            2
# 640            0            0
# 609            0            0
#
#                                                   Леммы  Кластер  \
# 926                           сварочный работа за тонна        0
# 1209       сварочный работа за тонна металлоконструкция        0
# 1105  стоимость сварочный монтажный работа трубопров...        0
# 1199              цена сварочный работа за тонна металл        0
# 961                 стоимость сварочный работа за тонна        0
# ...                                                 ...      ...
# 3239                            термообработка металл 5      613
# 618           машиностроение и металлообработка в китай      614
# 459                            металлообработка в китай      614
# 640              искать исполнитель по металлообработка      615
# 609                        металлообработка исполнитель      615
#
#                                       Название_кластера
# 926                      [сварочный, работа, за, тонна]
# 1209  [сварочный, работа, за, тонна, металлоконструк...
# 1105  [стоимость, сварочный, монтажный, работа, труб...
# 1199       [цена, сварочный, работа, за, тонна, металл]
# 961           [стоимость, сварочный, работа, за, тонна]
# ...                                                 ...
# 3239                        [термообработка, металл, 5]
# 618     [машиностроение, и, металлообработка, в, китай]
# 459                        [металлообработка, в, китай]
# 640         [искать, исполнитель, по, металлообработка]
# 609                     [металлообработка, исполнитель]
#
# [3080 rows x 7 columns]

# %% [markdown]
# Название каждого кластера будет состоять из всех слов, которые встречаются во фразах во всем кластере.

# %% [markdown]
# Сводная таблица со сложением всех фраз из кластера:

# %%
df_cluster_with_name = df2.pivot_table(index=['Кластер'],
                          values='Название_кластера',
                          aggfunc='sum').reset_index()

# %% [markdown]
# Печать несколькольких строк:

# %%
df_cluster_with_name
# Out:
#      Кластер                                  Название_кластера
# 0          0  [сварочный, работа, за, тонна, сварочный, рабо...
# 1          1  [металлообработка, фрезерный, работа, работа, ...
# 2          2  [прайс, на, сварочный, работа, отопление, прай...
# 3          3  [токарный, работа, по, дерево, для, начинающий...
# 4          4  [сварочный, работа, метр, погонный, метр, свар...
# ..       ...                                                ...
# 611      611  [вид, работа, который, выполняться, на, фрезер...
# 612      612                  [металлопрокат, металлообработка]
# 613      613  [справочник, по, термообработка, металл, термо...
# 614      614  [машиностроение, и, металлообработка, в, китай...
# 615      615  [искать, исполнитель, по, металлообработка, ме...
#
# [616 rows x 2 columns]

# %% [markdown]
# Удаление дубликатов слов в каждой строке столбца "Название кластера".<br>
# Чтобы удалить дубликаты слов, превратим list в set и снова в list:

# %%
df_cluster_with_name['Название_кластера'] = df_cluster_with_name['Название_кластера'].apply(lambda x: list(set(x)))

# %%
df_cluster_with_name
# Out:
#      Кластер                                  Название_кластера
# 0          0  [за, металлоконструкция, тонна, сварочный, в, ...
# 1          1  [машинка, фрезерный, копировальный, 5, работа,...
# 2          2    [на, прайс, отопление, сварочный, работа, лист]
# 3          3  [по, на, работа, начинающий, для, сварочный, ф...
# 4          4  [метр, погонный, сварочный, работа, стоимость,...
# ..       ...                                                ...
# 611      611  [выполняться, на, при, токарный, который, выпо...
# 612      612                  [металлопрокат, металлообработка]
# 613      613  [по, нагрев, температура, старение, для, спб, ...
# 614      614    [машиностроение, китай, в, и, металлообработка]
# 615      615        [по, исполнитель, искать, металлообработка]
#
# [616 rows x 2 columns]

# %% [markdown]
# Удаление предлогов из оставшихся в списках слов:

# %%
for pretext in list_of_pretext['predlogi']:
    for cluster_name in df_cluster_with_name['Название_кластера']:
        if pretext in cluster_name:
            cluster_name.remove(pretext)

# %%
df_cluster_with_name
# Out:
#      Кластер                                  Название_кластера
# 0          0  [металлоконструкция, тонна, сварочный, металл,...
# 1          1  [машинка, фрезерный, копировальный, 5, работа,...
# 2          2        [прайс, отопление, сварочный, работа, лист]
# 3          3  [по, работа, начинающий, сварочный, фрезерный,...
# 4          4  [метр, погонный, сварочный, работа, стоимость,...
# ..       ...                                                ...
# 611      611  [выполняться, токарный, который, выполнять, ст...
# 612      612                  [металлопрокат, металлообработка]
# 613      613  [по, нагрев, температура, старение, спб, 5, це...
# 614      614          [машиностроение, китай, металлообработка]
# 615      615        [по, исполнитель, искать, металлообработка]
#
# [616 rows x 2 columns]

# %% [markdown]
# Удаление квадратных скобок:

# %%
def extract_words(cluster_name):
        return ', '.join(cluster_name)

# %%
df_cluster_with_name['Название_кластера'] = df_cluster_with_name['Название_кластера'].apply(extract_words)

# %%
df_cluster_with_name
# Out:
#      Кластер                                  Название_кластера
# 0          0  металлоконструкция, тонна, сварочный, металл, ...
# 1          1  машинка, фрезерный, копировальный, 5, работа, ...
# 2          2          прайс, отопление, сварочный, работа, лист
# 3          3  по, работа, начинающий, сварочный, фрезерный, ...
# 4          4  метр, погонный, сварочный, работа, стоимость, ...
# ..       ...                                                ...
# 611      611  выполняться, токарный, который, выполнять, ста...
# 612      612                    металлопрокат, металлообработка
# 613      613  по, нагрев, температура, старение, спб, 5, цен...
# 614      614            машиностроение, китай, металлообработка
# 615      615          по, исполнитель, искать, металлообработка
#
# [616 rows x 2 columns]

# %% [markdown]
# ### Слияние таблицы с название кластера и основной таблицы

# %% [markdown]
# Объединение сводной таблицы df_cluster_with_name, в которой названия кластера строятся из всех слов с общей таблицей df. Каждому номеру кластера в общей таблице присвоится название в столбце Название_кластера:

# %%
df = df.merge(df_cluster_with_name, on='Кластер')

# %%
df
# Out:
#                                                   Фраза  Базовая частота  \
# 0                             сварочные работы за тонну               99
# 1          сварочные работы за тонну металлоконструкций               19
# 2     стоимость сварочно монтажных работ трубопровод...               29
# 3                 цена сварочных работ за тонну металла               20
# 4                    стоимость сварочных работ за тонну               71
# ...                                                 ...              ...
# 3075                           термообработка металла 5                1
# 3076          машиностроение и металлообработка в китае                2
# 3077                           металлообработка в китае                5
# 3078                ищу исполнителя по металлообработке                2
# 3079                       металлообработка исполнители                3
#
#       Частота **  Частота *!*  \
# 0              1            0
# 1              1            1
# 2             29           29
# 3             20           20
# 4             28           28
# ...          ...          ...
# 3075           0            0
# 3076           0            0
# 3077           2            2
# 3078           0            0
# 3079           0            0
#
#                                                   Леммы  Кластер  \
# 0                             сварочный работа за тонна        0
# 1          сварочный работа за тонна металлоконструкция        0
# 2     стоимость сварочный монтажный работа трубопров...        0
# 3                 цена сварочный работа за тонна металл        0
# 4                   стоимость сварочный работа за тонна        0
# ...                                                 ...      ...
# 3075                            термообработка металл 5      613
# 3076          машиностроение и металлообработка в китай      614
# 3077                           металлообработка в китай      614
# 3078             искать исполнитель по металлообработка      615
# 3079                       металлообработка исполнитель      615
#
#                                       Название_кластера
# 0     металлоконструкция, тонна, сварочный, металл, ...
# 1     металлоконструкция, тонна, сварочный, металл, ...
# 2     металлоконструкция, тонна, сварочный, металл, ...
# 3     металлоконструкция, тонна, сварочный, металл, ...
# 4     металлоконструкция, тонна, сварочный, металл, ...
# ...                                                 ...
# 3075  по, нагрев, температура, старение, спб, 5, цен...
# 3076            машиностроение, китай, металлообработка
# 3077            машиностроение, китай, металлообработка
# 3078          по, исполнитель, искать, металлообработка
# 3079          по, исполнитель, искать, металлообработка
#
# [3080 rows x 7 columns]

# %% [markdown]
# ### Посчитаем длину фраз

# %% [markdown]
# Разбиваем фразу на слова:

# %%
df['Длина_фразы_без_предлогов'] = df['Фраза'].str.split()

# %% [markdown]
# Удаление предлогов:

# %%
for pretext in list_of_pretext['predlogi']:
    for splitted_phrase in df['Длина_фразы_без_предлогов']:
        if pretext in splitted_phrase:
            splitted_phrase.remove(pretext)

# %%
df
# Out:
#                                                   Фраза  Базовая частота  \
# 0                             сварочные работы за тонну               99
# 1          сварочные работы за тонну металлоконструкций               19
# 2     стоимость сварочно монтажных работ трубопровод...               29
# 3                 цена сварочных работ за тонну металла               20
# 4                    стоимость сварочных работ за тонну               71
# ...                                                 ...              ...
# 3075                           термообработка металла 5                1
# 3076          машиностроение и металлообработка в китае                2
# 3077                           металлообработка в китае                5
# 3078                ищу исполнителя по металлообработке                2
# 3079                       металлообработка исполнители                3
#
#       Частота **  Частота *!*  \
# 0              1            0
# 1              1            1
# 2             29           29
# 3             20           20
# 4             28           28
# ...          ...          ...
# 3075           0            0
# 3076           0            0
# 3077           2            2
# 3078           0            0
# 3079           0            0
#
#                                                   Леммы  Кластер  \
# 0                             сварочный работа за тонна        0
# 1          сварочный работа за тонна металлоконструкция        0
# 2     стоимость сварочный монтажный работа трубопров...        0
# 3                 цена сварочный работа за тонна металл        0
# 4                   стоимость сварочный работа за тонна        0
# ...                                                 ...      ...
# 3075                            термообработка металл 5      613
# 3076          машиностроение и металлообработка в китай      614
# 3077                           металлообработка в китай      614
# 3078             искать исполнитель по металлообработка      615
# 3079                       металлообработка исполнитель      615
#
#                                       Название_кластера  \
# 0     металлоконструкция, тонна, сварочный, металл, ...
# 1     металлоконструкция, тонна, сварочный, металл, ...
# 2     металлоконструкция, тонна, сварочный, металл, ...
# 3     металлоконструкция, тонна, сварочный, металл, ...
# 4     металлоконструкция, тонна, сварочный, металл, ...
# ...                                                 ...
# 3075  по, нагрев, температура, старение, спб, 5, цен...
# 3076            машиностроение, китай, металлообработка
# 3077            машиностроение, китай, металлообработка
# 3078          по, исполнитель, искать, металлообработка
# 3079          по, исполнитель, искать, металлообработка
#
#                               Длина_фразы_без_предлогов
# 0                            [сварочные, работы, тонну]
# 1        [сварочные, работы, тонну, металлоконструкций]
# 2     [стоимость, сварочно, монтажных, работ, трубоп...
# 3              [цена, сварочных, работ, тонну, металла]
# 4                  [стоимость, сварочных, работ, тонну]
# ...                                                 ...
# 3075                       [термообработка, металла, 5]
# 3076          [машиностроение, металлообработка, китае]
# 3077                          [металлообработка, китае]
# 3078           [ищу, исполнителя, по, металлообработке]
# 3079                    [металлообработка, исполнители]
#
# [3080 rows x 8 columns]

# %% [markdown]
# Замена всех списков со словами на длину этих списков:

# %%
df['Длина_фразы_без_предлогов'] = df['Длина_фразы_без_предлогов'].apply(lambda x: len(x))

# %%
df
# Out:
#                                                   Фраза  Базовая частота  \
# 0                             сварочные работы за тонну               99
# 1          сварочные работы за тонну металлоконструкций               19
# 2     стоимость сварочно монтажных работ трубопровод...               29
# 3                 цена сварочных работ за тонну металла               20
# 4                    стоимость сварочных работ за тонну               71
# ...                                                 ...              ...
# 3075                           термообработка металла 5                1
# 3076          машиностроение и металлообработка в китае                2
# 3077                           металлообработка в китае                5
# 3078                ищу исполнителя по металлообработке                2
# 3079                       металлообработка исполнители                3
#
#       Частота **  Частота *!*  \
# 0              1            0
# 1              1            1
# 2             29           29
# 3             20           20
# 4             28           28
# ...          ...          ...
# 3075           0            0
# 3076           0            0
# 3077           2            2
# 3078           0            0
# 3079           0            0
#
#                                                   Леммы  Кластер  \
# 0                             сварочный работа за тонна        0
# 1          сварочный работа за тонна металлоконструкция        0
# 2     стоимость сварочный монтажный работа трубопров...        0
# 3                 цена сварочный работа за тонна металл        0
# 4                   стоимость сварочный работа за тонна        0
# ...                                                 ...      ...
# 3075                            термообработка металл 5      613
# 3076          машиностроение и металлообработка в китай      614
# 3077                           металлообработка в китай      614
# 3078             искать исполнитель по металлообработка      615
# 3079                       металлообработка исполнитель      615
#
#                                       Название_кластера  \
# 0     металлоконструкция, тонна, сварочный, металл, ...
# 1     металлоконструкция, тонна, сварочный, металл, ...
# 2     металлоконструкция, тонна, сварочный, металл, ...
# 3     металлоконструкция, тонна, сварочный, металл, ...
# 4     металлоконструкция, тонна, сварочный, металл, ...
# ...                                                 ...
# 3075  по, нагрев, температура, старение, спб, 5, цен...
# 3076            машиностроение, китай, металлообработка
# 3077            машиностроение, китай, металлообработка
# 3078          по, исполнитель, искать, металлообработка
# 3079          по, исполнитель, искать, металлообработка
#
#       Длина_фразы_без_предлогов
# 0                             3
# 1                             4
# 2                             6
# 3                             5
# 4                             4
# ...                         ...
# 3075                          3
# 3076                          3
# 3077                          2
# 3078                          4
# 3079                          2
#
# [3080 rows x 8 columns]

# %% [markdown]
# ### Определим город, если он встречается во фразе

# %%
df['Город'] = df['Леммы'].str.split()

# %%
def find_city(splitted_lemmas):
    for city in list_of_cities['goroda'].str.lower():
        if city in splitted_lemmas:
            return city

# %%
df['Город'] = df['Город'].apply(find_city)

# %%
df['Город'].fillna(value='-', inplace=True)

# %%
df.head(30)
# Out:
#                                                 Фраза  Базовая частота  \
# 0                           сварочные работы за тонну               99
# 1        сварочные работы за тонну металлоконструкций               19
# 2   стоимость сварочно монтажных работ трубопровод...               29
# 3               цена сварочных работ за тонну металла               20
# 4                  стоимость сварочных работ за тонну               71
# 5   стоимость сварочных работ за тонну металлоконс...               18
# 6                      сварочные работы цена за тонну               26
# 7          стоимость сварочных работ за тонну металла               25
# 8                   металлообработка фрезерные работы                4
# 9                           работа фрезерной машинкой                1
# 10                 токарно фрезерная металлообработка                2
# 11                         фрезерная металлообработка               15
# 12                           токарно фрезерные работы              273
# 13                                 фрезерные работы 5                9
# 14                         продольно фрезерные работы                1
# 15         металлообработка токарные фрезерные работы                1
# 16                     работа копировальном фрезерном                5
# 17                                 фрезерные работы г                1
# 18                                   фрезерные работы             1002
# 19                прайс на сварочные работы отопление                1
# 20              прайс лист отопление сварочные работы                1
# 21           токарные работы по дереву для начинающих               17
# 22          фрезерные работы по дереву для начинающих                6
# 23           работа на токарном станке для начинающих               22
# 24          работа начинающих токарных станках дереву               14
# 25          работа сварочным аппаратом для начинающих                5
# 26       работа со сварочным аппаратом для начинающих                5
# 27                    фрезерные работы для начинающих                6
# 28          токарные работы по металлу для начинающих               11
# 29                    сварочные работы для начинающих               13
#
#     Частота **  Частота *!*  \
# 0            1            0
# 1            1            1
# 2           29           29
# 3           20           20
# 4           28           28
# 5           17           17
# 6            2            2
# 7           25           25
# 8            0            0
# 9            0            0
# 10           0            0
# 11           0            0
# 12          20           20
# 13           0            0
# 14           0            0
# 15           0            0
# 16           0            0
# 17           0            0
# 18          44           43
# 19           0            0
# 20           0            0
# 21           4            4
# 22           0            0
# 23           0            0
# 24           0            0
# 25           0            0
# 26           5            5
# 27           0            0
# 28           0            0
# 29           1            1
#
#                                                 Леммы  Кластер  \
# 0                           сварочный работа за тонна        0
# 1        сварочный работа за тонна металлоконструкция        0
# 2   стоимость сварочный монтажный работа трубопров...        0
# 3               цена сварочный работа за тонна металл        0
# 4                 стоимость сварочный работа за тонна        0
# 5   стоимость сварочный работа за тонна металлокон...        0
# 6                      сварочный работа цена за тонна        0
# 7          стоимость сварочный работа за тонна металл        0
# 8                   металлообработка фрезерный работа        1
# 9                            работа фрезерный машинка        1
# 10                токарный фрезерный металлообработка        1
# 11                         фрезерный металлообработка        1
# 12                          токарный фрезерный работа        1
# 13                                 фрезерный работа 5        1
# 14                         продольно фрезерный работа        1
# 15         металлообработка токарный фрезерный работа        1
# 16                     работа копировальный фрезерный        1
# 17                               фрезерный работа год        1
# 18                                   фрезерный работа        1
# 19                прайс на сварочный работа отопление        2
# 20              прайс лист отопление сварочный работа        2
# 21           токарный работа по дерево для начинающий        3
# 22          фрезерный работа по дерево для начинающий        3
# 23           работа на токарный станок для начинающий        3
# 24           работа начинающий токарный станок дерево        3
# 25            работа сварочный аппарат для начинающий        3
# 26          работа с сварочный аппарат для начинающий        3
# 27                    фрезерный работа для начинающий        3
# 28           токарный работа по металл для начинающий        3
# 29                    сварочный работа для начинающий        3
#
#                                     Название_кластера  \
# 0   металлоконструкция, тонна, сварочный, металл, ...
# 1   металлоконструкция, тонна, сварочный, металл, ...
# 2   металлоконструкция, тонна, сварочный, металл, ...
# 3   металлоконструкция, тонна, сварочный, металл, ...
# 4   металлоконструкция, тонна, сварочный, металл, ...
# 5   металлоконструкция, тонна, сварочный, металл, ...
# 6   металлоконструкция, тонна, сварочный, металл, ...
# 7   металлоконструкция, тонна, сварочный, металл, ...
# 8   машинка, фрезерный, копировальный, 5, работа, ...
# 9   машинка, фрезерный, копировальный, 5, работа, ...
# 10  машинка, фрезерный, копировальный, 5, работа, ...
# 11  машинка, фрезерный, копировальный, 5, работа, ...
# 12  машинка, фрезерный, копировальный, 5, работа, ...
# 13  машинка, фрезерный, копировальный, 5, работа, ...
# 14  машинка, фрезерный, копировальный, 5, работа, ...
# 15  машинка, фрезерный, копировальный, 5, работа, ...
# 16  машинка, фрезерный, копировальный, 5, работа, ...
# 17  машинка, фрезерный, копировальный, 5, работа, ...
# 18  машинка, фрезерный, копировальный, 5, работа, ...
# 19          прайс, отопление, сварочный, работа, лист
# 20          прайс, отопление, сварочный, работа, лист
# 21  по, работа, начинающий, сварочный, фрезерный, ...
# 22  по, работа, начинающий, сварочный, фрезерный, ...
# 23  по, работа, начинающий, сварочный, фрезерный, ...
# 24  по, работа, начинающий, сварочный, фрезерный, ...
# 25  по, работа, начинающий, сварочный, фрезерный, ...
# 26  по, работа, начинающий, сварочный, фрезерный, ...
# 27  по, работа, начинающий, сварочный, фрезерный, ...
# 28  по, работа, начинающий, сварочный, фрезерный, ...
# 29  по, работа, начинающий, сварочный, фрезерный, ...
#
#     Длина_фразы_без_предлогов Город
# 0                           3     -
# 1                           4     -
# 2                           6     -
# 3                           5     -
# 4                           4     -
# 5                           5     -
# 6                           4     -
# 7                           5     -
# 8                           3     -
# 9                           3     -
# 10                          3     -
# 11                          2     -
# 12                          3     -
# 13                          3     -
# 14                          3     -
# 15                          4     -
# 16                          3     -
# 17                          3     -
# 18                          2     -
# 19                          4     -
# 20                          5     -
# 21                          5     -
# 22                          5     -
# 23                          4     -
# 24                          5     -
# 25                          4     -
# 26                          4     -
# 27                          3     -
# 28                          5     -
# 29                          3     -

# %% [markdown]
# ### Определим является ли запрос информационным

# %%
df['Информационный_характер'] = df['Фраза'].str.split()

# %%
def find_questions(splitted_phrase):
    for word in list_of_questions['vopros'].str.lower():
        if word in splitted_phrase:
            return 'инфо'

# %%
df['Информационный_характер'] = df['Информационный_характер'].apply(find_questions)

# %%
df['Информационный_характер'].fillna(value='-', inplace=True)

# %%
df
# Out:
#                                                   Фраза  Базовая частота  \
# 0                             сварочные работы за тонну               99
# 1          сварочные работы за тонну металлоконструкций               19
# 2     стоимость сварочно монтажных работ трубопровод...               29
# 3                 цена сварочных работ за тонну металла               20
# 4                    стоимость сварочных работ за тонну               71
# ...                                                 ...              ...
# 3075                           термообработка металла 5                1
# 3076          машиностроение и металлообработка в китае                2
# 3077                           металлообработка в китае                5
# 3078                ищу исполнителя по металлообработке                2
# 3079                       металлообработка исполнители                3
#
#       Частота **  Частота *!*  \
# 0              1            0
# 1              1            1
# 2             29           29
# 3             20           20
# 4             28           28
# ...          ...          ...
# 3075           0            0
# 3076           0            0
# 3077           2            2
# 3078           0            0
# 3079           0            0
#
#                                                   Леммы  Кластер  \
# 0                             сварочный работа за тонна        0
# 1          сварочный работа за тонна металлоконструкция        0
# 2     стоимость сварочный монтажный работа трубопров...        0
# 3                 цена сварочный работа за тонна металл        0
# 4                   стоимость сварочный работа за тонна        0
# ...                                                 ...      ...
# 3075                            термообработка металл 5      613
# 3076          машиностроение и металлообработка в китай      614
# 3077                           металлообработка в китай      614
# 3078             искать исполнитель по металлообработка      615
# 3079                       металлообработка исполнитель      615
#
#                                       Название_кластера  \
# 0     металлоконструкция, тонна, сварочный, металл, ...
# 1     металлоконструкция, тонна, сварочный, металл, ...
# 2     металлоконструкция, тонна, сварочный, металл, ...
# 3     металлоконструкция, тонна, сварочный, металл, ...
# 4     металлоконструкция, тонна, сварочный, металл, ...
# ...                                                 ...
# 3075  по, нагрев, температура, старение, спб, 5, цен...
# 3076            машиностроение, китай, металлообработка
# 3077            машиностроение, китай, металлообработка
# 3078          по, исполнитель, искать, металлообработка
# 3079          по, исполнитель, искать, металлообработка
#
#       Длина_фразы_без_предлогов Город Информационный_характер
# 0                             3     -                       -
# 1                             4     -                       -
# 2                             6     -                       -
# 3                             5     -                       -
# 4                             4     -                       -
# ...                         ...   ...                     ...
# 3075                          3     -                       -
# 3076                          3     -                       -
# 3077                          2     -                       -
# 3078                          4     -                       -
# 3079                          2     -                       -
#
# [3080 rows x 10 columns]

# %% [markdown]
# ### Определим является ли запрос "коммерческим"

# %%
df['Коммерческий_характер'] = df['Леммы'].str.split()

# %%
def find_commerce(splitted_lemmas):
    for word in list_of_commerce_words['komm'].str.lower():
        if word in splitted_lemmas:
            return 'коммерческий'

# %%
df['Коммерческий_характер'] = df['Коммерческий_характер'].apply(find_commerce)

# %%
df['Коммерческий_характер'].fillna(value='-', inplace=True)

# %%
df
# Out:
#                                                   Фраза  Базовая частота  \
# 0                             сварочные работы за тонну               99
# 1          сварочные работы за тонну металлоконструкций               19
# 2     стоимость сварочно монтажных работ трубопровод...               29
# 3                 цена сварочных работ за тонну металла               20
# 4                    стоимость сварочных работ за тонну               71
# ...                                                 ...              ...
# 3075                           термообработка металла 5                1
# 3076          машиностроение и металлообработка в китае                2
# 3077                           металлообработка в китае                5
# 3078                ищу исполнителя по металлообработке                2
# 3079                       металлообработка исполнители                3
#
#       Частота **  Частота *!*  \
# 0              1            0
# 1              1            1
# 2             29           29
# 3             20           20
# 4             28           28
# ...          ...          ...
# 3075           0            0
# 3076           0            0
# 3077           2            2
# 3078           0            0
# 3079           0            0
#
#                                                   Леммы  Кластер  \
# 0                             сварочный работа за тонна        0
# 1          сварочный работа за тонна металлоконструкция        0
# 2     стоимость сварочный монтажный работа трубопров...        0
# 3                 цена сварочный работа за тонна металл        0
# 4                   стоимость сварочный работа за тонна        0
# ...                                                 ...      ...
# 3075                            термообработка металл 5      613
# 3076          машиностроение и металлообработка в китай      614
# 3077                           металлообработка в китай      614
# 3078             искать исполнитель по металлообработка      615
# 3079                       металлообработка исполнитель      615
#
#                                       Название_кластера  \
# 0     металлоконструкция, тонна, сварочный, металл, ...
# 1     металлоконструкция, тонна, сварочный, металл, ...
# 2     металлоконструкция, тонна, сварочный, металл, ...
# 3     металлоконструкция, тонна, сварочный, металл, ...
# 4     металлоконструкция, тонна, сварочный, металл, ...
# ...                                                 ...
# 3075  по, нагрев, температура, старение, спб, 5, цен...
# 3076            машиностроение, китай, металлообработка
# 3077            машиностроение, китай, металлообработка
# 3078          по, исполнитель, искать, металлообработка
# 3079          по, исполнитель, искать, металлообработка
#
#       Длина_фразы_без_предлогов Город Информационный_характер  \
# 0                             3     -                       -
# 1                             4     -                       -
# 2                             6     -                       -
# 3                             5     -                       -
# 4                             4     -                       -
# ...                         ...   ...                     ...
# 3075                          3     -                       -
# 3076                          3     -                       -
# 3077                          2     -                       -
# 3078                          4     -                       -
# 3079                          2     -                       -
#
#      Коммерческий_характер
# 0                        -
# 1                        -
# 2             коммерческий
# 3             коммерческий
# 4             коммерческий
# ...                    ...
# 3075                     -
# 3076                     -
# 3077                     -
# 3078                     -
# 3079                     -
#
# [3080 rows x 11 columns]

# %% [markdown]
# ## Создание конечной готовой таблицы

# %% [markdown]
# Фразы с региональной принадлежностью определим в отдельный датафрейм - все, что не "спб", "санкт-петербург" и "-":

# %%
df_ready_regions = df[
    (df['Город'] != 'спб') & 
    (df['Город'] != 'санкт-петербург') & 
    (df['Город'] != '-')
]

# %% [markdown]
# Приоритетный регион - или "спб" или "санкт-петербург" или "-"::

# %%
df_ready = df[
    (df['Город'] == 'спб') |
    (df['Город'] == 'санкт-петербург') | 
    (df['Город'] == '-')
]

# %% [markdown]
# ## Экспорт

# %%
writer_kernel = pd.ExcelWriter('ready_table.xlsx', engine='xlsxwriter')
df_ready.to_excel(writer_kernel, sheet_name='Основной список запросов', index=False)
df_ready_regions.to_excel(writer_kernel, sheet_name='Регионы', index=False)
writer_kernel.save()
